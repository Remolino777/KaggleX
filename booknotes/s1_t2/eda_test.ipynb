# %%
import pandas as pd

# %%
path = r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\KagelX\KaggleX\data\test.csv'

# %%
data =pd.read_csv(path)

# %%
df = data.copy()

# %%
import matplotlib.pyplot as plt

# %%
df['model_year'].describe()
# Out:
# count    36183.000000
# mean      2015.063953
# std          5.589336
# min       1974.000000
# 25%       2012.000000
# 50%       2016.000000
# 75%       2019.000000
# max       2024.000000
# Name: model_year, dtype: float64

# %%
plt.boxplot(df['model_year'])
plt.show()
