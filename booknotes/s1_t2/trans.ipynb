# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

import seaborn as sns
import numpy as np

import joblib as jb

# %% [markdown]
# ### Load data

# %%
path = r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\KagelX\KaggleX\data\clean\clean_data_2.parquet'

# %%
df = pd.read_parquet(path)

# %%
df.head(3)
# Out:
#     brand         model  model_year  milage fuel_type  \
# 0    Ford  F-150 Lariat        2018   74349  Gasoline
# 1     BMW         335 i        2007   80000  Gasoline
# 2  Jaguar     XF Luxury        2009   91491  Gasoline
#
#                                               engine  transmission ext_col  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel  10-Speed A/T    Blue
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...   6-Speed M/T   Black
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel   6-Speed A/T  Purple
#
#   int_col       accident  price
# 0    Gray  None reported  11000
# 1   Black  None reported   8250
# 2   Beige  None reported  15000

# %% [markdown]
# ### categorical value count

# %%
# Generar gráficos de barras para cada columna categórica
for i in df.select_dtypes(exclude='number').columns:
    print(df[i].value_counts())
    print(100*'-')
# Out:
# brand
# BMW              7369
# Ford             6706
# Mercedes-Benz    5087
# Chevrolet        4424
# Audi             2922
# Porsche          2627
# Toyota           2315
# Lexus            2257
# Jeep             2247
# Land             1995
# Cadillac         1565
# Nissan           1252
# GMC              1076
# Dodge            1011
# RAM               966
# INFINITI          957
# Lincoln           767
# Mazda             748
# Subaru            739
# Hyundai           694
# Jaguar            661
# Volkswagen        628
# Honda             624
# Acura             580
# Kia               526
# Volvo             452
# MINI              364
# Maserati          293
# Bentley           284
# Chrysler          258
# Genesis           249
# Buick             228
# Mitsubishi        182
# Hummer            176
# Pontiac           149
# Alfa              144
# Rolls-Royce       142
# Lamborghini       122
# Tesla             110
# Ferrari            87
# Saturn             58
# Scion              53
# Aston              50
# McLaren            43
# Rivian             27
# Mercury            20
# FIAT               16
# Lotus              12
# Suzuki              4
# Maybach             3
# Lucid               2
# Plymouth            1
# Bugatti             1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# model
# F-150 XLT             780
# M3 Base               682
# X5 xDrive35i          615
# F-150 Lariat          496
# Mustang GT Premium    466
#                      ...
# Suburban 2500           1
# TLX Tech                1
# Rogue Sport S           1
# A8 4.0                  1
# S-10 LS                 1
# Name: count, Length: 1827, dtype: int64
# ----------------------------------------------------------------------------------------------------
# fuel_type
# Gasoline          49439
# Hybrid             1766
# E85 Flex Fuel      1479
# Diesel             1109
# –                   294
# Plug-In Hybrid      182
# not supported         4
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# engine
# 300.0HP 3.0L Straight 6 Cylinder Engine Gasoline Fuel    1452
# 355.0HP 5.3L 8 Cylinder Engine Gasoline Fuel             1125
# 240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel             1054
# 285.0HP 3.6L V6 Cylinder Engine Gasoline Fuel             979
# 420.0HP 6.2L 8 Cylinder Engine Gasoline Fuel              893
#                                                          ...
# 4.4 Liter GDI DOHC Twin Turbo                               1
# 3.0 Liter Twin Turbo                                        1
# 150.0HP 2.0L 4 Cylinder Engine Diesel Fuel                  1
# 266.0HP Electric Motor Electric Fuel System                 1
# 151.0HP Electric Motor Hydrogen Fuel                        1
# Name: count, Length: 1061, dtype: int64
# ----------------------------------------------------------------------------------------------------
# transmission
# A/T                                                   16757
# 8-Speed A/T                                            7287
# Transmission w/Dual Shift Mode                         6454
# 6-Speed A/T                                            5944
# 6-Speed M/T                                            3618
# 7-Speed A/T                                            3415
# 10-Speed A/T                                           2187
# 8-Speed Automatic                                      1189
# 5-Speed A/T                                            1185
# 9-Speed A/T                                            1073
# 4-Speed A/T                                             764
# 5-Speed M/T                                             718
# CVT Transmission                                        692
# 10-Speed Automatic                                      642
# 6-Speed Automatic                                       516
# Automatic                                               441
# M/T                                                     359
# 9-Speed Automatic                                       344
# 7-Speed Automatic with Auto-Shift                       110
# 7-Speed M/T                                             104
# Automatic CVT                                            95
# 1-Speed A/T                                              60
# 8-Speed Automatic with Auto-Shift                        55
# Transmission Overdrive Switch                            54
# 7-Speed Automatic                                        41
# 6-Speed Manual                                           34
# 5-Speed Automatic                                        24
# 7-Speed Manual                                           22
# 6-Speed Automatic with Auto-Shift                        17
# 8-Speed Manual                                            9
# 4-Speed Automatic                                         8
# 7-Speed                                                   7
# –                                                         7
# 7-Speed DCT Automatic                                     6
# 1-Speed Automatic                                         6
# 6-Speed Electronically Controlled Automatic with O        6
# 10-Speed Automatic with Overdrive                         5
# 2-Speed A/T                                               5
# 6-Speed                                                   3
# 9-Speed Automatic with Auto-Shift                         2
# SCHEDULED FOR OR IN PRODUCTION                            2
# 6 Speed Mt                                                2
# CVT-F                                                     1
# F                                                         1
# Variable                                                  1
# 6 Speed At/Mt                                             1
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# ext_col
# Black                      15078
# White                      13422
# Gray                        7909
# Silver                      5161
# Blue                        4668
#                            ...
# Balloon White                  1
# Firenze Red Metallic           1
# Orca Black Metallic            1
# Radiant Red Metallic II        1
# Magnetic Gray Clearcoat        1
# Name: count, Length: 260, dtype: int64
# ----------------------------------------------------------------------------------------------------
# int_col
# Black                31820
# Beige                 7995
# Gray                  6252
# Brown                 2239
# Red                   1499
#                      ...
# Cloud                    1
# Black/Red                1
# Oyster/Black             1
# Oyster W/Contrast        1
# Red/Black                1
# Name: count, Length: 124, dtype: int64
# ----------------------------------------------------------------------------------------------------
# accident
# None reported                             39896
# At least 1 accident or damage reported    14377
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### dummy columns

# %%
# label_brand = LabelEncoder()
# label_model = LabelEncoder()
#label_fuel = LabelEncoder()
label_engine = LabelEncoder()
# label_trans = LabelEncoder()
# label_ext_col = LabelEncoder()
# label_ext_int = LabelEncoder()
label_accident = LabelEncoder()

# %%
beta = ['price', 'engine', 'accident', 'milage', 'model_year']

# %%
df1 =df[beta].copy()

# %%
#df1['brand'] = label_brand.fit_transform(df['brand'])
#df1['model'] = label_brand.fit_transform(df['model'])
#df1['fuel_type'] = label_fuel.fit_transform(df['fuel_type'])
df1['engine'] = label_engine.fit_transform(df['engine'])
#df1['transmission'] = label_trans.fit_transform(df['transmission'])
#df1['ext_col'] = label_ext_col.fit_transform(df['ext_col'])
#df1['int_col'] = label_ext_int.fit_transform(df['int_col'])
df1['accident'] = label_accident.fit_transform(df['accident'])

# %%
# jb.dump(label_engine, 'label_engine.pkl')
# jb.dump(label_model, 'label_model.pkl')
# jb.dump(label_fuel, 'label_fuel.pkl')
# jb.dump(label_brand, 'label_brand.pkl')
# jb.dump(label_trans, 'label_trans.pkl')
# jb.dump(label_ext_col, 'label_ext_col.pkl')
# jb.dump(label_ext_int, 'label_int_col.pkl')
# jb.dump(label_accident, 'label_accident.pkl')
# Out:
# ['label_accident.pkl']

# %%
df1.head(5)
# Out:
#    price  engine  accident  milage  model_year
# 0  11000     719         1   74349        2018
# 1   8250     534         1   80000        2007
# 2  15000     541         1   91491        2009
# 3  63500     646         1    2437        2022
# 4   7850     219         1  111000        2001

# %%
df1.describe()
# Out:
#               price        engine      accident         milage    model_year
# count  5.427300e+04  54273.000000  54273.000000   54273.000000  54273.000000
# mean   3.921844e+04    565.570799      0.735098   72746.175667   2015.091979
# std    7.282634e+04    262.411316      0.441285   50469.490448      5.588909
# min    2.000000e+03      0.000000      0.000000     100.000000   1974.000000
# 25%    1.550000e+04    347.000000      0.000000   32268.000000   2012.000000
# 50%    2.800000e+04    582.000000      1.000000   66107.000000   2016.000000
# 75%    4.500000e+04    785.000000      1.000000  102000.000000   2019.000000
# max    2.954083e+06   1060.000000      1.000000  405000.000000   2024.000000

# %%
df1.shape
# Out:
# (54273, 5)

# %%
df1 = df1[df1['milage'] < 300000]
df1 = df1[df1['price'] < 500000]
df1 = df1[df1['model_year'] > 1990]

# %%
df1.shape
# Out:
# (54034, 5)

# %% [markdown]
# ### target 'price' distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df1['price'], bins=50, kde=True)
plt.title('Distribución de la columna "price"')
plt.xlabel('Price')
plt.ylabel('Frecuencia')
plt.show()

# %%
plt.boxplot(df1['price'])
plt.show()

# %%
df1['milage'].describe()
# Out:
# count     54034.000000
# mean      72229.790687
# std       49248.229449
# min         100.000000
# 25%       32268.000000
# 50%       66000.000000
# 75%      101900.000000
# max      249999.000000
# Name: milage, dtype: float64

# %%
df1.head(2)
# Out:
#    price  engine  accident  milage  model_year
# 0  11000     719         1   74349        2018
# 1   8250     534         1   80000        2007

# %%
df1['milage_ratio'] = df1['milage']/df1['model_year']
df1['delta'] = df1['engine'] + df1['accident'] 


#df1['5_plus'] = ((df1['milage'] > 5000) & (df1['model_year'] < 2019)).astype(int)

# %%
df1.head(1)
# Out:
#    price  engine  accident  milage  model_year  milage_ratio  delta
# 0  11000     719         1   74349        2018     36.842914    720

# %% [markdown]
# ### Feature 2

# %%
from sklearn.cluster import KMeans

# %%
inertia = []
k_range = range(1,11)

# %%
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(df1[['engine','milage_ratio']])
    inertia.append(kmeans.inertia_)

# %%
plt.figure(figsize=(8, 4))
plt.plot(k_range, inertia, 'bo-', markersize=8)
plt.xlabel('Número de clusters k')
plt.ylabel('Inercia')
plt.title('Método del Codo para determinar el número óptimo de clusters')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=0)
df1["Cluster"] = kmeans.fit_predict(df1[['engine','milage_ratio']])
df1["Cluster"] = df1["Cluster"].astype("category")
df1['Cluster'] = df1['Cluster'].cat.codes


df1.head()
# Out:
#    price  engine  accident  milage  model_year  milage_ratio  delta  Cluster  \
# 0  11000     719         1   74349        2018     36.842914    720        1
# 1   8250     534         1   80000        2007     39.860488    535        0
# 2  15000     541         1   91491        2009     45.540567    542        0
# 3  63500     646         1    2437        2022      1.205242    647        0
# 4   7850     219         1  111000        2001     55.472264    220        2
#
#    Cluster_1
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
print(kmeans)
# Out:
# KMeans(n_clusters=3, random_state=0) KMeans(n_clusters=3, random_state=0)

# %%
df1['Cluster'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 54034 entries, 0 to 54272
# Series name: Cluster
# Non-Null Count  Dtype
# --------------  -----
# 54034 non-null  int8
# dtypes: int8(1)
# memory usage: 474.9 KB

# %%
import joblib as jb

# %%
jb.dump(kmeans,r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\KagelX\KaggleX\booknotes\s1_t2\kmeans_model.pkl')
# Out:
# ['D:\\0_Respaldo\\0_Proyectos_2024\\ML_proyects\\KagelX\\KaggleX\\booknotes\\s1_t2\\kmeans_model_1.pkl']

# %%
sns.relplot(
    x="engine", y="milage_ratio", hue="Cluster", data=df1, height=6,
)

# %%
df1.head(5)
# Out:
#    price  engine  accident  milage  model_year  milage_ratio  delta  Cluster
# 0  11000     719         1   74349        2018     36.842914    720        1
# 1   8250     534         1   80000        2007     39.860488    535        0
# 2  15000     541         1   91491        2009     45.540567    542        0
# 3  63500     646         1    2437        2022      1.205242    647        0
# 4   7850     219         1  111000        2001     55.472264    220        2

# %% [markdown]
# ### feature engenieering

# %%
# df1['milage_ratio'] = df1['milage']/df1['model_year']

# %%
# df1.head(5)

# %%
# df1['log_milage'] = np.log(df1['milage'])

# %%
#discret years
# df1['years_range'] = pd.cut(df['model_year'], bins=[0,2010,2014,2015,2016,2017,2018,2024], labels=['modelo 0 a 2010', 'modelo 2010 a 2014', 'modelo 2014 a 2015', 'modelo 2015 a 2016', 'modelo 2016 a 2017', 'modelo 2017 a 2018','modelo 2018 a 2024'])

# %%
# dummies = pd.get_dummies(df1['years_range'], dtype='int64')
# df1 = pd.concat([df1, dummies], axis=1)

# %%
# del df1['years_range']

# %%
# df1.head(2)

# %%
# dummies = pd.get_dummies(df1['brand'], dtype='int64')
# df1 = pd.concat([df1, dummies], axis=1)

# %%
# del df1['brand']

# %%
# df1.head(2)

# %%
# dummies = pd.get_dummies(df1['engine'], dtype='int64')
# df1 = pd.concat([df1, dummies], axis=1)

# %%
# del df1['engine']

# %%
# df1.head(2)

# %%
# dummies = pd.get_dummies(df1['accident'], dtype='int64')
# df1 = pd.concat([df1, dummies], axis=1)
# del df1['accident']

# %%
# df1.head(1)

# %% [markdown]
# ### Export parquet file

# %%
path = r'D:\0_Respaldo\0_Proyectos_2024\ML_proyects\KagelX\KaggleX\booknotes\s1_t2\beta_data.parquet'
df1.to_parquet(path)
